# %%
#library files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#inserting  dataset, Q1
df = pd.read_csv('/content/loan_dataset.csv')
df
# Out:
#              loan_id source       financial_institution  interest_rate  \
# 0       268055008619      Z  Turner, Baldwin and Rhodes          4.250
# 1       672831657627      Y  Swanson, Newton and Miller          4.875
# 2       742515242108      Z              Thornton-Davis          3.250
# 3       601385667462      X                       OTHER          4.750
# 4       273870029961      X                       OTHER          4.750
# ...              ...    ...                         ...            ...
# 116053  382119962287      Y               Browning-Hart          4.125
# 116054  582803915466      Z                       OTHER          3.000
# 116055  837922316947      X                       OTHER          3.875
# 116056  477343182138      X                       OTHER          4.250
# 116057  763308490661      Z              Thornton-Davis          3.375
#
#         unpaid_principal_bal  loan_term origination_date first_payment_date  \
# ...

# %%
#rows and colums of dataset, Q2
df.shape
# Out:
# (116058, 26)

# %%
#getting info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116058 entries, 0 to 116057
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   loan_id                   116058 non-null  int64
#  1   source                    116058 non-null  object
#  2   financial_institution     116058 non-null  object
#  3   interest_rate             116058 non-null  float64
#  4   unpaid_principal_bal      116058 non-null  int64
#  5   loan_term                 116058 non-null  int64
#  6   origination_date          116058 non-null  object
#  7   first_payment_date        116058 non-null  object
#  8   loan_to_value             116058 non-null  int64
#  9   number_of_borrowers       116058 non-null  float64
#  10  debt_to_income_ratio      116058 non-null  float64
#  11  borrower_credit_score     116058 non-null  float64
#  12  loan_purpose              116058 non-null  object
# ...

# %%
#discription of columns in dataset
df.describe()
# Out:
#             loan_id  interest_rate  unpaid_principal_bal      loan_term  \
# count  1.160580e+05  116058.000000          1.160580e+05  116058.000000
# mean   5.494155e+11       3.868961          2.082262e+05     292.280997
# std    2.597560e+11       0.461020          1.146851e+05      89.762415
# min    1.000009e+11       2.250000          1.100000e+04      60.000000
# 25%    3.244656e+11       3.500000          1.200000e+05     180.000000
# 50%    5.486239e+11       3.875000          1.830000e+05     360.000000
# 75%    7.743034e+11       4.125000          2.780000e+05     360.000000
# max    9.999971e+11       6.750000          1.200000e+06     360.000000
#
#        loan_to_value  number_of_borrowers  debt_to_income_ratio  \
# count  116058.000000        116058.000000         116058.000000
# mean       67.431939             1.593186             30.742293
# std        17.291719             0.491242              9.730798
# ...

# %%
#no of uniques in a columns
df.nunique()
# Out:
# source                        3
# financial_institution        19
# interest_rate               923
# unpaid_principal_bal        646
# loan_term                   140
# origination_date              3
# first_payment_date            4
# loan_to_value                92
# number_of_borrowers           2
# debt_to_income_ratio         58
# borrower_credit_score       221
# insurance_percent            14
# co-borrower_credit_score    216
# insurance_type                2
# m1                            4
# m2                            5
# m3                            6
# m4                            7
# m5                            8
# m6                            9
# m7                           10
# m8                           10
# m9                           11
# m10                          12
# m11                          13
# m12                          13
# m13                           2
# dtype: int64

# %%
#no of null values in each column
df.isnull().sum()
# Out:
# loan_id                     0
# source                      0
# financial_institution       0
# interest_rate               0
# unpaid_principal_bal        0
# loan_term                   0
# origination_date            0
# first_payment_date          0
# loan_to_value               0
# number_of_borrowers         0
# debt_to_income_ratio        0
# borrower_credit_score       0
# loan_purpose                0
# insurance_percent           0
# co-borrower_credit_score    0
# insurance_type              0
# m1                          0
# m2                          0
# m3                          0
# m4                          0
# m5                          0
# m6                          0
# m7                          0
# m8                          0
# m9                          0
# m10                         0
# m11                         0
# m12                         0
# m13                         0
# dtype: int64

# %%
#droping unique values
df.drop('loan_id', axis=1, inplace=True)

# %%
df.head()
# Out:
#   source       financial_institution  interest_rate  unpaid_principal_bal  \
# 0      Z  Turner, Baldwin and Rhodes          4.250                214000
# 1      Y  Swanson, Newton and Miller          4.875                144000
# 2      Z              Thornton-Davis          3.250                366000
# 3      X                       OTHER          4.750                135000
# 4      X                       OTHER          4.750                124000
#
#    loan_term origination_date first_payment_date  loan_to_value  \
# 0        360       2012-03-01            05/2012             95
# 1        360       2012-01-01            03/2012             72
# 2        180       2012-01-01            03/2012             49
# 3        360       2012-02-01            04/2012             46
# 4        360       2012-02-01            04/2012             80
#
#    number_of_borrowers  debt_to_income_ratio  ...  m4 m5  m6  m7  m8  m9  m10  \
# ...

# %%
df.drop('loan_purpose', axis=1, inplace=True)

# %%
df.head()
# Out:
#   source       financial_institution  interest_rate  unpaid_principal_bal  \
# 0      Z  Turner, Baldwin and Rhodes          4.250                214000
# 1      Y  Swanson, Newton and Miller          4.875                144000
# 2      Z              Thornton-Davis          3.250                366000
# 3      X                       OTHER          4.750                135000
# 4      X                       OTHER          4.750                124000
#
#    loan_term origination_date first_payment_date  loan_to_value  \
# 0        360       2012-03-01            05/2012             95
# 1        360       2012-01-01            03/2012             72
# 2        180       2012-01-01            03/2012             49
# 3        360       2012-02-01            04/2012             46
# 4        360       2012-02-01            04/2012             80
#
#    number_of_borrowers  debt_to_income_ratio  ...  m4  m5  m6  m7  m8  m9  \
# ...

# %%
#creating dummy  variables from categorical variables
pd.get_dummies(df)
# Out:
#         source  interest_rate  unpaid_principal_bal  loan_term  loan_to_value  \
# 0            2          4.250                214000        360             95
# 1            1          4.875                144000        360             72
# 2            2          3.250                366000        180             49
# 3            0          4.750                135000        360             46
# 4            0          4.750                124000        360             80
# ...        ...            ...                   ...        ...            ...
# 116053       1          4.125                153000        360             88
# 116054       2          3.000                150000        120             35
# 116055       0          3.875                166000        360             58
# 116056       0          4.250                169000        360             74
# 116057       2          3.375                252000        180             29
#
# ...

# %%
#finding unique values in source
df['source'].unique()
# Out:
# array([2, 1, 0])

# %%
#replacing values in source to int vals
df['source'] = df['source'].replace({'X': 0, 'Y': 1, 'Z': 2})

# %%
#checking unique vals
df['source'].unique()
# Out:
# array([2, 1, 0])

# %%
df.head()
# Out:
#    source       financial_institution  interest_rate  unpaid_principal_bal  \
# 0       2  Turner, Baldwin and Rhodes          4.250                214000
# 1       1  Swanson, Newton and Miller          4.875                144000
# 2       2              Thornton-Davis          3.250                366000
# 3       0                       OTHER          4.750                135000
# 4       0                       OTHER          4.750                124000
#
#    loan_term origination_date first_payment_date  loan_to_value  \
# 0        360       2012-03-01            05/2012             95
# 1        360       2012-01-01            03/2012             72
# 2        180       2012-01-01            03/2012             49
# 3        360       2012-02-01            04/2012             46
# 4        360       2012-02-01            04/2012             80
#
#    number_of_borrowers  debt_to_income_ratio  ...  m4  m5  m6  m7  m8  m9  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116058 entries, 0 to 116057
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   source                    116058 non-null  int64
#  1   financial_institution     116058 non-null  object
#  2   interest_rate             116058 non-null  float64
#  3   unpaid_principal_bal      116058 non-null  int64
#  4   loan_term                 116058 non-null  int64
#  5   origination_date          116058 non-null  object
#  6   first_payment_date        116058 non-null  object
#  7   loan_to_value             116058 non-null  int64
#  8   number_of_borrowers       116058 non-null  float64
#  9   debt_to_income_ratio      116058 non-null  float64
#  10  borrower_credit_score     116058 non-null  float64
#  11  insurance_percent         116058 non-null  float64
#  12  co-borrower_credit_score  116058 non-null  float64
# ...

# %%
#simplifying
df.drop('financial_institution', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116058 entries, 0 to 116057
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   source                    116058 non-null  int64
#  1   interest_rate             116058 non-null  float64
#  2   unpaid_principal_bal      116058 non-null  int64
#  3   loan_term                 116058 non-null  int64
#  4   origination_date          116058 non-null  object
#  5   first_payment_date        116058 non-null  object
#  6   loan_to_value             116058 non-null  int64
#  7   number_of_borrowers       116058 non-null  float64
#  8   debt_to_income_ratio      116058 non-null  float64
#  9   borrower_credit_score     116058 non-null  float64
#  10  insurance_percent         116058 non-null  float64
#  11  co-borrower_credit_score  116058 non-null  float64
#  12  insurance_type            116058 non-null  float64
# ...

# %% [markdown]
# Q3,linear regression

# %%
#labeling
X = df['debt_to_income_ratio'].values
Y = df['insurance_percent'].values

# %%
plt.scatter(X, Y, color = 'blue', label='Scatter Plot')
plt.title('Relation btw intreset rate and loan term')
plt.xlabel('debt_to_income_ratio')
plt.ylabel('insurance_percent')
plt.legend(loc=4)
plt.show()

# %%
X=X.reshape(-1,1)
Y=Y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=lr.predict(X_test)

# %%
a = lr.coef_
b = lr.intercept_,
print("Estimated model slope, a:" , a)
print("Estimated model intercept, b:" , b)
# Out:
# Estimated model slope, a: [[0.05488276]]
# Estimated model intercept, b: (array([1.10609841]),)

# %%
lr.predict(X) [0:5]
# Out:
# array([[2.31351917],
#        [3.52093992],
#        [2.91722955],
#        [3.52093992],
#        [3.46605716]])

# %%
lr.predict([[24]])
# Out:
# array([[2.42328469]])

# %% [markdown]
# random forest

# %%
from sklearn.datasets import make_blobs

X, Y = make_blobs(n_samples=116058, centers=4, random_state=0, cluster_std=1.0)
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50);

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier().fit(X, Y)

# %% [markdown]
# svm model

# %%
plt.xlabel('debt_to_income_ratio')
plt.ylabel('insurance_percent')
plt.scatter(df['debt_to_income_ratio'], df['number_of_borrowers'], color='green', marker='+')

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 81240
# 34818

# %%
from sklearn.svm import SVC

# %%
model = SVC(kernel='linear')

# %%
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
predictions = model.predict(X_test)
print(predictions)
# Out:
# [1 0 3 ... 3 2 2]

# %%
percentage = model.score(X_test, Y_test)

# %%
from sklearn.metrics import confusion_matrix
res = confusion_matrix(Y_test, predictions)
print("Confusion Matrix")
print(res)
print(f"Test Set: {len(X_test)}")
print(f"Accuracy = {percentage*100} %")
# Out:
# Confusion Matrix
# [[7593  308  644  164]
#  [ 254 8221  127    0]
#  [ 578  139 7981   44]
#  [ 139    0   44 8582]]
# Test Set: 34818
# Accuracy = 92.98925842954795 %

# %% [markdown]
# Q4,cross calidation
